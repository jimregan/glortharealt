# %% [markdown]
# <a href="https://colab.research.google.com/gist/jimregan/fefcac3f58af9eafd9bbdbd8fba194d7/run-dlib-face-detection-on-youtube-video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install face_recognition
# !pip install youtube-dl
# Out:
# ...
#      |████████████████████████████████| 100.2MB 72.1MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# ...
#      |████████████████████████████████| 1.8MB 9.9MB/s
# ...

# %%
# !apt-get install wget
# !wget http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# !wget http://dlib.net/files/dlib_face_recognition_resnet_model_v1.dat.bz2
# !wget http://dlib.net/files/shape_predictor_68_face_landmarks.dat.bz2
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# wget is already the newest version (1.19.4-1ubuntu2.2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 16 not upgraded.
# --2019-05-13 05:52:27--  http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# Resolving dlib.net (dlib.net)... 107.180.26.78
# Connecting to dlib.net (dlib.net)|107.180.26.78|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5706710 (5.4M)
# Saving to: ‘shape_predictor_5_face_landmarks.dat.bz2’
#
# shape_predictor_5_f 100%[===================>]   5.44M  2.35MB/s    in 2.3s
#
# 2019-05-13 05:52:29 (2.35 MB/s) - ‘shape_predictor_5_face_landmarks.dat.bz2’ saved [5706710/5706710]
#
# --2019-05-13 05:52:30--  http://dlib.net/files/dlib_face_recognition_resnet_model_v1.dat.bz2
# ...

# %%
# !bunzip2 shape_predictor_5_face_landmarks.dat.bz2
# !bunzip2 dlib_face_recognition_resnet_model_v1.dat.bz2
# !bunzip2 shape_predictor_68_face_landmarks.dat.bz2

# %%
# !git clone https://gist.github.com/jimregan/edc35d82fd953f2c58bec632d93680a1 scripts
# Out:
# Cloning into 'scripts'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 47 (delta 16), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (47/47), done.

# %%
# !youtube-dl --id -a scripts/input.txt
# Out:
# [youtube] 6ACiYVKbmPM: Downloading webpage
# [youtube] 6ACiYVKbmPM: Downloading video info webpage
# [youtube] 6ACiYVKbmPM: Downloading MPD manifest
# [dashsegments] Total fragments: 12
# [download] Destination: 6ACiYVKbmPM.f136.mp4
# [download] 100% of 11.03MiB in 00:01
# [dashsegments] Total fragments: 7
# [download] Destination: 6ACiYVKbmPM.f140.m4a
# [download] 100% of 893.47KiB in 00:00
# [ffmpeg] Merging formats into "6ACiYVKbmPM.mp4"
# Deleting original file 6ACiYVKbmPM.f136.mp4 (pass -k to keep)
# Deleting original file 6ACiYVKbmPM.f140.m4a (pass -k to keep)
# [youtube] 75aYGKQdQxo: Downloading webpage
# [youtube] 75aYGKQdQxo: Downloading video info webpage
# WARNING: Requested formats are incompatible for merge and will be merged into mkv.
# [download] Destination: 75aYGKQdQxo.f135.mp4
# [download] 100% of 3.99MiB in 00:00
# [download] Destination: 75aYGKQdQxo.f251.webm
# [download] 100% of 892.08KiB in 00:00
# [ffmpeg] Merging formats into "75aYGKQdQxo.mkv"
# ...

# %%
# !for i in *.mp4 *.mkv;do bash scripts/convert.sh $i;done
# Out:
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
# ...

# %%
# !cat scripts/input.txt |while read i;do echo $i; python scripts/detect.py $i; ls $i*.txt | zip res.zip -@ ;done
# Out:
# 6ACiYVKbmPM

# %%
# !rm -rf scripts *_out

# %%
# !find 6ACiYVKbmPM_out -type f|zip 6ACiYVKbmPM.zip -@
# Out:
#   adding: 6ACiYVKbmPM_out/output4/face_1_4.jpg (deflated 7%)
#   adding: 6ACiYVKbmPM_out/output4/face_2_4.jpg (deflated 7%)
#   adding: 6ACiYVKbmPM_out/output4/face_0_4.jpg (deflated 7%)
#   adding: 6ACiYVKbmPM_out/output0/face_222_0.jpg (deflated 5%)
#   adding: 6ACiYVKbmPM_out/output0/face_157_0.jpg (deflated 7%)
#   adding: 6ACiYVKbmPM_out/output0/face_263_0.jpg (deflated 6%)
#   adding: 6ACiYVKbmPM_out/output0/face_268_0.jpg (deflated 6%)
#   adding: 6ACiYVKbmPM_out/output0/face_94_0.jpg (deflated 6%)
#   adding: 6ACiYVKbmPM_out/output0/face_102_0.jpg (deflated 5%)
#   adding: 6ACiYVKbmPM_out/output0/face_8_0.jpg (deflated 5%)
#   adding: 6ACiYVKbmPM_out/output0/face_23_0.jpg (deflated 6%)
#   adding: 6ACiYVKbmPM_out/output0/face_80_0.jpg (deflated 5%)
#   adding: 6ACiYVKbmPM_out/output0/face_143_0.jpg (deflated 6%)
#   adding: 6ACiYVKbmPM_out/output0/face_259_0.jpg (deflated 5%)
#   adding: 6ACiYVKbmPM_out/output0/face_188_0.jpg (deflated 5%)
# ...
