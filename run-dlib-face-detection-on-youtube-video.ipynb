# %% [markdown]
# <a href="https://colab.research.google.com/gist/jimregan/3a9e6e9a8be92e98bd1afb375ff8a841/run-dlib-face-detection-on-youtube-video.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install face_recognition
# !pip install youtube-dl
# Out:
# ...
#      |████████████████████████████████| 100.2MB 42.2MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# ...
#      |████████████████████████████████| 1.8MB 4.7MB/s
# ...

# %%
# !youtube-dl --id sS8qsTRpkOs
# !ls
# Out:
# [youtube] sS8qsTRpkOs: Downloading webpage
# [youtube] sS8qsTRpkOs: Downloading video info webpage
# [youtube] sS8qsTRpkOs: Downloading MPD manifest
# [dashsegments] Total fragments: 10
# [download] Destination: sS8qsTRpkOs.f135.mp4
# [download] 100% of 3.47MiB in 00:02
# [dashsegments] Total fragments: 10
# [download] Destination: sS8qsTRpkOs.f140.m4a
# [download] 100% of 664.39KiB in 00:02
# [ffmpeg] Merging formats into "sS8qsTRpkOs.mp4"
# Deleting original file sS8qsTRpkOs.f135.mp4 (pass -k to keep)
# Deleting original file sS8qsTRpkOs.f140.m4a (pass -k to keep)
# sample_data  sS8qsTRpkOs.mp4

# %%
# !mkdir sS8qsTRpkOs
# !ffmpeg -y -i sS8qsTRpkOs.mp4 -q:v 1 -r 25 sS8qsTRpkOs/%08d.jpg
# Out:
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
# ...

# %%
# !ls TJ9njRet4iA/
# Out:
# 00000001.jpg  00000299.jpg  00000597.jpg  00000895.jpg	00001193.jpg
# 00000002.jpg  00000300.jpg  00000598.jpg  00000896.jpg	00001194.jpg
# 00000003.jpg  00000301.jpg  00000599.jpg  00000897.jpg	00001195.jpg
# 00000004.jpg  00000302.jpg  00000600.jpg  00000898.jpg	00001196.jpg
# 00000005.jpg  00000303.jpg  00000601.jpg  00000899.jpg	00001197.jpg
# 00000006.jpg  00000304.jpg  00000602.jpg  00000900.jpg	00001198.jpg
# 00000007.jpg  00000305.jpg  00000603.jpg  00000901.jpg	00001199.jpg
# 00000008.jpg  00000306.jpg  00000604.jpg  00000902.jpg	00001200.jpg
# 00000009.jpg  00000307.jpg  00000605.jpg  00000903.jpg	00001201.jpg
# 00000010.jpg  00000308.jpg  00000606.jpg  00000904.jpg	00001202.jpg
# 00000011.jpg  00000309.jpg  00000607.jpg  00000905.jpg	00001203.jpg
# 00000012.jpg  00000310.jpg  00000608.jpg  00000906.jpg	00001204.jpg
# 00000013.jpg  00000311.jpg  00000609.jpg  00000907.jpg	00001205.jpg
# 00000014.jpg  00000312.jpg  00000610.jpg  00000908.jpg	00001206.jpg
# ...

# %%
# !apt-get install wget
# !wget http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# !wget http://dlib.net/files/dlib_face_recognition_resnet_model_v1.dat.bz2
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# wget is already the newest version (1.19.4-1ubuntu2.2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 16 not upgraded.
# --2019-05-11 16:13:40--  http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# Resolving dlib.net (dlib.net)... 107.180.26.78
# Connecting to dlib.net (dlib.net)|107.180.26.78|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5706710 (5.4M)
# Saving to: ‘shape_predictor_5_face_landmarks.dat.bz2’
#
# shape_predictor_5_f 100%[===================>]   5.44M  4.98MB/s    in 1.1s
#
# 2019-05-11 16:13:41 (4.98 MB/s) - ‘shape_predictor_5_face_landmarks.dat.bz2’ saved [5706710/5706710]
#
# --2019-05-11 16:13:42--  http://dlib.net/files/dlib_face_recognition_resnet_model_v1.dat.bz2
# ...

# %%
# !bunzip2 shape_predictor_5_face_landmarks.dat.bz2
# !bunzip2 dlib_face_recognition_resnet_model_v1.dat.bz2

# %%
import sys
import os
import dlib
import glob

predictor_path = 'shape_predictor_5_face_landmarks.dat'
face_rec_model_path = 'dlib_face_recognition_resnet_model_v1.dat'
faces_folder_path = 'sS8qsTRpkOs'

detector = dlib.get_frontal_face_detector()
sp = dlib.shape_predictor(predictor_path)
facerec = dlib.face_recognition_model_v1(face_rec_model_path)

output = open('{}.txt'.format(faces_folder_path), 'w+')

for f in glob.glob(os.path.join(faces_folder_path, "*.jpg")):
  img = dlib.load_rgb_image(f)
  dets = detector(img, 1)
  
  for k, d in enumerate(dets):
    output.write("File: {} Detection {}: Left: {} Top: {} Right: {} Bottom: {}\n".format(
            f, k, d.left(), d.top(), d.right(), d.bottom()))
    
output.close()

# %%
# !tail -f TJ9njRet4iA.txt
# Out:
# File: TJ9njRet4iA/00000825.jpg Detection 0: Left: 384 Top: 87 Right: 446 Bottom: 149File: TJ9njRet4iA/00000284.jpg Detection 0: Left: 398 Top: 94 Right: 460 Bottom: 156File: TJ9njRet4iA/00000613.jpg Detection 0: Left: 405 Top: 87 Right: 467 Bottom: 149File: TJ9njRet4iA/00000808.jpg Detection 0: Left: 370 Top: 88 Right: 444 Bottom: 163File: TJ9njRet4iA/00000776.jpg Detection 0: Left: 395 Top: 96 Right: 469 Bottom: 171File: TJ9njRet4iA/00000143.jpg Detection 0: Left: 391 Top: 94 Right: 453 Bottom: 156File: TJ9njRet4iA/00001124.jpg Detection 0: Left: 349 Top: 87 Right: 411 Bottom: 149File: TJ9njRet4iA/00000575.jpg Detection 0: Left: 370 Top: 87 Right: 432 Bottom: 149File: TJ9njRet4iA/00001182.jpg Detection 0: Left: 314 Top: 84 Right: 366 Bottom: 136File: TJ9njRet4iA/00000699.jpg Detection 0: Left: 384 Top: 87 Right: 446 Bottom: 149File: TJ9njRet4iA/00000590.jpg Detection 0: Left: 398 Top: 87 Right: 460 Bottom: 149File: TJ9njRet4iA/00000197.jpg Detection 0: Left: 377 Top: 94 Right: 439 B
# ...
